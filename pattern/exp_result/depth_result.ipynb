# %%
gnnt = [ 
    0.8682, # 6
    0.8681, 
    0.8686, 
    0.8689, 
    0.8689, 
    0.8687, 
    0.8683, 
    0.8689, 
    0.8659, 
    0.8620, 
    0.8678, 
    0.8635, 
    0.8602, 
    0.8616,
    0.8611 # 20
]

# %%
parallel = [ 
    0.8693,
    0.8689,
    0.8692,
    0.8690,
    0.8698,
    0.8691,
    0.8683,
    0.8688,
    0.8673,
    0.8657,
    0.8640,
    0.8618,
    0.8642, 
    0.8598,  
    0.8609
]

# %%
lgi = [ 
    0.8694,  # 6
    0.8692, 
    0.8690, 
    0.8690, 
    0.8695, 
    0.8701, 
    0.8695, 
    0.8694, 
    0.8699, 
    0.8700, 
    0.8702, 
    0.8697, 
    0.8699,
    0.8697, 
    0.8697  # 20
]

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = list(range(6, 21)) 

plt.axis([5, 21, 0.860, 0.874])
plt.plot(x, gnnt, 'bo--', label='GNN+Transformer') 
plt.plot(x, parallel, 'gv--', label='Parallel GT')
plt.plot(x, lgi, 'rs--', label='LGI-GT') 

plt.legend(loc='upper right') 
plt.xlabel('model depth') 
plt.ylabel('accuracy') 
# plt.show() 
plt.savefig('depth_study.pdf', dpi=600)
